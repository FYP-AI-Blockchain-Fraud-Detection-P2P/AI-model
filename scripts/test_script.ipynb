# %%
import pandas as pd
data = pd.read_csv('../data/final_data_cleaned.csv')

# %%
data
# Out:
#          loan_amnt  funded_amnt  term  int_rate  installment  emp_length  \
# 0         0.050633         2500    36  0.321262        84.92          10
# 1         0.746835        30000    60  0.530763       777.23          10
# 2         0.113924         5000    36  0.492991       180.69           6
# 3         0.088608         4000    36  0.530763       146.51          10
# 4         0.746835        30000    60  0.421729       731.78          10
# ...            ...          ...   ...       ...          ...         ...
# 2260663   0.291139        12000    60  0.341511       279.72          10
# 2260664   0.291139        12000    60  0.798676       358.01           0
# 2260665   0.240506        10000    36  0.260125       332.10          10
# 2260666   0.291139        12000    60  0.628505       327.69          10
# 2260667   0.406329        16550    60  0.628505       451.94           3
#
#          annual_inc  zip_code      dti  delinq_2yrs  ...  \
# ...
